# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/content/Entertainer.csv")

# %%
data.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  Year of Breakthrough  \
# 0            Adele                    F        1988                  2008
# 1   Angelina Jolie                    F        1975                  1999
# 2  Aretha Franklin                    F        1942                  1967
# 3      Bette Davis                    F        1908                  1934
# 4      Betty White                    F        1922                  1952
#
#                           Breakthrough Name  Year of First Oscar  \
# 0                                        19               2009.0
# 1                         Girl, Interrupted               1999.0
# 2  I Never Loved a Man (The Way I Love You)               1968.0
# 3                          Of Human Bondage               1935.0
# 4                      Life with Elilzabeth               1976.0
#
#    Year of Last Major Work   Year of Death
# 0                      2016            NaN
# 1                      2016            NaN
# 2                      2014            NaN
# 3                      1989         1989.0
# 4                      2016            NaN

# %%
data.describe().T
# Out:
#                           count         mean        std     min     25%  \
# Birth Year                 70.0  1935.585714  24.135783  1889.0  1916.0
# Year of Breakthrough       70.0  1964.228571  22.411935  1915.0  1949.5
# Year of First Oscar        64.0  1976.234375  22.170152  1929.0  1962.0
# Year of Last Major Work    70.0  1998.971429  22.874561  1933.0  1980.0
# Year of Death              30.0  1988.133333  20.483355  1942.0  1977.0
#
#                              50%      75%     max
# Birth Year                1935.5  1954.00  1988.0
# Year of Breakthrough      1963.5  1983.50  2008.0
# Year of First Oscar       1978.0  1993.00  2017.0
# Year of Last Major Work   2014.0  2016.00  2016.0
# Year of Death             1989.5  2003.75  2016.0

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Entertainer', 'Gender (traditional)', 'Breakthrough Name'], dtype='object')
# Numerical Variables:
# ['Birth Year', 'Year of Breakthrough', 'Year of First Oscar', 'Year of Last Major Work ', 'Year of Death']

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Birth Year
# Skew : 0.15
# Year of Breakthrough
# Skew : -0.04
# Year of First Oscar
# Skew : -0.25
# Year of Last Major Work
# Skew : -1.18
# Year of Death
# Skew : -0.36

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data=data.drop([],axis=1))
plt.show()
